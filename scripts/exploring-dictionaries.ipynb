# %%
import requests
import re
import pandas as pd
import xml.etree.ElementTree as ET
import json
import os
import sys
import matplotlib.pyplot as plt
from collections import Counter

# %%
# Define the URL for the XML file
url = "https://raw.githubusercontent.com/sarahalang/alchemical-dictionaries/refs/heads/main/Ruland1612/Ruland.xml"

# Fetch the XML file from the URL
response = requests.get(url)

# %%
xml_content = response.content
tree = ET.ElementTree(ET.fromstring(xml_content))
root = tree.getroot()
TEI_NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

# %%
entries = root.findall('.//tei:entry', TEI_NS)

# %%
entry_list = []
# Parse each entry
# Parse each entry
for entry in entries:
    entry_dict = {}
    # Extract entry attributes
    entry_dict['ID'] = entry.attrib.get('n', None)  # Replace "No ID" with None
    entry_dict['entry_xml'] = entry
    entry_dict['Type'] = entry.attrib.get('type', None)  # Replace "No Type" with None
    entry_dict['XML_ID'] = entry.attrib.get('{http://www.w3.org/XML/1998/namespace}id', None)  # Replace "No XML ID" with None

    # Extract lemma
    lemma = entry.find('.//tei:form[@type="lemma"]', TEI_NS)
    entry_dict['Lemma'] = lemma.text.strip() if lemma is not None else None

    # Extract phrase (if any)
    phrase = entry.find('.//tei:form[@type="phrase"]', TEI_NS)
    entry_dict['Phrase'] = phrase.text.strip() if phrase is not None else None

    # Extract variants
    variants = entry.findall('.//tei:form[@type="variant"]', TEI_NS)
    entry_dict['Variants'] = [variant.text.strip() for variant in variants if variant is not None]

    # Extract notes
    notes = entry.findall('.//tei:note', TEI_NS)
    entry_dict['Notes'] = []
    for note in notes:
        # Handle all nested text within a note, including <lb/> and other sub-elements
        note_text = ''.join(note.itertext()).replace('\n', ' ').replace('<lb/>', ' ').strip()
        entry_dict['Notes'].append(note_text)

    # Extract senses and definitions
    senses = entry.findall('.//tei:sense', TEI_NS)
    entry_dict['Definitions'] = []
    for sense in senses:
        # Extract direct text content of <sense>
        sense_text = ''.join(sense.itertext()).replace('\n', ' ').replace('<lb/>', ' ').strip()
        if sense_text:
            entry_dict['Definitions'].append(sense_text)

    # Extract quotes (translations)
    quotes = entry.findall('.//tei:quote', TEI_NS)
    entry_dict['Translations'] = [quote.text.strip() for quote in quotes if quote is not None]

    # Append entry dictionary to the list
    entry_list.append(entry_dict)

# %%
entries_df = pd.DataFrame(entry_list)

# %%
entries_df[1000:1020]
# Out:
#                                           ID  \
# 1000  Ruland1612-Coloratio-per-calorem-solum
# 1001     Ruland1612-Coloratio-per-ablutionem
# 1002                       Ruland1612-Colica
# 1003                     Ruland1612-Collecta
# 1004                    Ruland1612-Collectam
# 1005                    Ruland1612-Combustio
# 1006                       Ruland1612-Cometz
# 1007                      Ruland1612-Comisdi
# 1008                   Ruland1612-Comminutio
# 1009                    Ruland1612-Complexio
# 1010                   Ruland1612-Compositio
# 1011          Ruland1612-Commissurae-saxorum
# 1012                      Ruland1612-Compass
# 1013                       Ruland1612-Concha
# 1014                       Ruland1612-Conder
# 1015               Ruland1612-Confirmamentum
# 1016                 Ruland1612-Confortatiua
# 1017                     Ruland1612-Confusio
# 1018                   Ruland1612-Congelatio
# 1019                  Ruland1612-Congelatiua
#
#                                               entry_xml Type XML_ID  \
# 1000  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1001  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1002  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1003  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1004  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1005  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1006  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1007  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1008  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1009  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1010  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1011  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1012                                         [[[], []]]    C   None
# 1013  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1014  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1015  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1016  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1017  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1018  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
# 1019  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    C   None
#
#                             Lemma Phrase Variants Notes  \
# 1000  Coloratio per calorem solum   None       []    []
# 1001     Coloratio per ablutionem   None       []    []
# 1002                       Colica   None       []    []
# 1003                     Collecta   None       []    []
# 1004                    Collectam   None       []    []
# 1005                    Combustio   None       []    []
# 1006                       Cometz   None       []    []
# 1007                      Comisdi   None       []    []
# 1008                   Comminutio   None       []    []
# 1009                    Complexio   None       []    []
# 1010                   Compositio   None       []    []
# 1011          Commissurae saxorum   None       []    []
# 1012                      Compass   None       []    []
# 1013                       Concha   None       []    []
# 1014                       Conder   None       []    []
# 1015               Confirmamentum   None       []    []
# 1016                 Confortatiua   None       []    []
# 1017                     Confusio   None       []    []
# 1018                   Congelatio   None       []    []
# 1019                  Congelatiua   None       []    []
#
#                                             Definitions  \
# 1000  [est modus colorandi, cum e potentia in actum,...
# 1001  [est, cum fuscedines spiritales, aliaeque sord...
# 1002  [est tartarus resolutus in intestinis, morbusq...
# 1003  [, symbolum,                          Zubuß   ...
# 1004  [exigere a Dominis,                          Z...
# 1005  [est ignitio, corpora comburendo in caleem red...
# 1006                                 [est gutta semis.]
# 1007                          [id est, gummi Arabicum.]
# 1008  [est, cum in minutissimas partes per collisum ...
# 1009  [est natura partis. Alias est qualitas calidi ...
# 1010  [est diuersorum coadunatio.                   ...
# 1011                           [Absetzen deß Gesteinß.]
# 1012                     [instrumentum, cui iudex est.]
# 1013  [ein Glaßschale                       vel alue...
# 1014                          [id est, thus, olibanum.]
# 1015  [est astri corpus in homine, vel corpus side¬r...
# 1016  [Confortantia sunt medicamenta, quae          ...
# 1017  [quae est synchesis est commistio actu        ...
# 1018  [Wann die Materi dicklecht wirdt / fliesset ni...
# 1019  [sunt medicamenta fluxus insistentia, comprime...
#
#                                            Translations
# 1000                                                 []
# 1001                                                 []
# 1002                          [Bauchgrimmen die Mutter]
# 1003                                            [Zubuß]
# 1004                                    [Zubuß fordern]
# 1005                                                 []
# 1006                                                 []
# 1007                                                 []
# 1008                                                 []
# 1009                          [Es ist ein Eigen chafft]
# 1010                                                 []
# 1011                           [Absetzen deß Gesteinß.]
# 1012                                                 []
# 1013                                   [ein Glaßschale]
# 1014                                                 []
# 1015                   [Der gestirnte Leib im Menschen]
# 1016                                                 []
# 1017                                                 []
# 1018  [Wann die Materi dicklecht wirdt / fliesset ni...
# 1019      [Was die Fluͤß zusammen zeucht / stellt vnnd]

# %%
# for preprocessing the latin texts, we will use a module located outside of the current repository, specifically at the same level as the current project.
current_working_directory = os.getcwd()
relative_path = '../../latin-preprocessing/'  # change according to your location...
module_path = os.path.abspath(os.path.join(current_working_directory, relative_path))
if module_path not in sys.path:
    sys.path.insert(0, module_path)
# Now import the module
import tomela

# %%
doc = tomela.nlp("Mercurium metallorum,")
lemmatized_string = " ".join([t.lemma_ for t in doc if t.pos_ not in ["PUNCT"]]).lower()
lemmatized_string
# Out:
# 'mercurius metallum'

# %%
def lemmatizer(string):
    if string is not None:
        doc = tomela.nlp(string)
        lemmatized_list = []
        for t in doc:
            if t.pos_ not in ["PUNCT"]:
                if t.lemma_ == "":
                    lemmatized_list.append(t.text.lower())
                else:
                    lemmatized_list.append(t.lemma_.lower())
        lemmatized = " ".join(lemmatized_list)
    else:
        lemmatized = None
    if lemmatized == "":
        lemmatized = None
    return lemmatized
entries_df["relemmatized"] = entries_df["Lemma"].apply(lemmatizer)

# %%
entries_df[entries_df["Lemma"].str.contains("Mercurius", na=False)]
# Out:
#                                          ID  \
# 2049                   Ruland1612-Mercurius
# 2051     Ruland1612-Mercurius-crystallinus,
# 2052        Ruland1612-Mercurius-corallinus
# 2053            Ruland1612-Mercurius-crudus
# 2054             Ruland1612-Mercurius-laxus
# 2055  Ruland1612-Mercurius-argentipigmentum
# 2056        Ruland1612-Mercurius-metallorum
# 2057                   Ruland1612-Mercurius
# 2058                   Ruland1612-Mercurius
# 2059       Ruland1612-Mercurius-regeneratus
# 2060           Ruland1612-Mercurius-chambar
# 2062        Ruland1612-Mercurius-mineralium
# 2063        Ruland1612-Mercurius-metallorum
#
#                                               entry_xml Type XML_ID  \
# 2049  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2051  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2052  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2053  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2054  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2055  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2056  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2057  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2058                                         [[[], []]]    M   None
# 2059  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2060  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2062  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2063  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
#
#                            Lemma Phrase Variants Notes  \
# 2049                   Mercurius   None       []    []
# 2051     Mercurius crystallinus,   None       []    []
# 2052        Mercurius corallinus   None       []    []
# 2053            Mercurius crudus   None       []    []
# 2054             Mercurius laxus   None       []    []
# 2055  Mercurius argentipigmentum   None       []    []
# 2056        Mercurius metallorum   None       []    []
# 2057                   Mercurius   None       []    []
# 2058                   Mercurius   None       []    []
# 2059       Mercurius regeneratus   None       []    []
# 2060           Mercurius chambar   None       []    []
# 2062        Mercurius mineralium   None       []    []
# 2063        Mercurius metallorum   None       []    []
#
#                                             Definitions  \
# 2049  [id est, sulphur.                      Mercuri...
# 2051  [qui saepe sublimatus est in formam cry¬stalli...
# 2052  [qui per oleum ouorum &               aquas al...
# 2053  [est is, qui nondum separatus est a sua matric...
# 2054                            [est turbith minerale.]
# 2055  [ist Schwefel victriol, Alaun Saltz-dieweils d...
# 2056  [Ist darauß die Natur der Coͤrper gezo¬gen wir...
# 2057  [est principium materiale, vaporosum, naturę a...
# 2058                         [argentum viuum CC. S. Z.]
# 2059                         [est primum ens Mercurii.]
# 2060       [ist magnesia, fuessend Coͤrper und Wasser.]
# 2062  [est oleitas, vel vnctuositas de mineris auri ...
# 2063  [mercurius corporis                 praecipita...
#
#                                            Translations  \
# 2049  [Mercurius ist in allen Chymistischen Buͤchern...
# 2051                                                 []
# 2052                                                 []
# 2053                      [der noch in seim Ertz liget]
# 2054                                                 []
# 2055                     [ist Schwefel victriol, Alaun]
# 2056           [Ist darauß die Natur der Coͤrper gezo¬]
# 2057                                                 []
# 2058                                                 []
# 2059                                                 []
# 2060       [ist magnesia, fuessend Coͤrper und Wasser.]
# 2062            [Das Oel auß dem Gold oder Silber Ertz]
# 2063          [Wann die Metallen in ihr erste materiam]
#
#                     relemmatized
# 2049                   mercurius
# 2051      mercurius crystallinus
# 2052        mercurius corallinus
# 2053            mercurius crudus
# 2054             mercurius laxus
# 2055  mercurius argentipigmentus
# 2056          mercurius metallum
# 2057                   mercurius
# 2058                   mercurius
# 2059          mercurius regenero
# 2060           mercurius chambar
# 2062         mercurius mineralis
# 2063          mercurius metallum

# %%
emlap_metadata = pd.read_csv("https://raw.githubusercontent.com/CCS-ZCU/EMLAP_ETL/refs/heads/master/data/emlap_metadata.csv", sep=";")
emlap_metadata.head(5)
# Out:
#                   working_title     No.  is_done  is_noscemus  if_noscemus_id  \
# 0        Augurello, Chrysopoeia  100001     True         True        713324.0
# 1         Pseudo-Lull, Secretis  100002     True        False             NaN
# 2  Pantheus, Ars Transmutatione  100003     True        False             NaN
# 3        Pantheus, Commentarium  100004     True        False             NaN
# 4        Pantheus, Voarchadumia  100005     True        False             NaN
#
#    #if is_noscemus = True, don't transcribe  AUTHORSHIP  is_one_author  \
# 0                                       NaN         NaN           True
# 1                                       NaN         NaN           True
# 2                                       NaN         NaN           True
# 3                                       NaN         NaN           True
# 4                                       NaN         NaN           True
#
#    #if more than 1 author skip section and choose compendium below  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    is_author_known  ...                                               link  \
# 0             True  ...       https://wiki.uibk.ac.at/noscemus/Chrysopoeia
# 1             True  ...  https://www.digitale-sammlungen.de/en/view/bsb...
# 2             True  ...                                                NaN
# 3             True  ...  https://www.digitale-sammlungen.de/en/view/bsb...
# 4             True  ...                                                NaN
#
#   source_of_file  origin_of_copy REFERENCES catalogue_reference  \
# 0       Noscemus         Unknown        NaN       Noscemus Wiki
# 1            MDZ             MBS        NaN         Hirsch 1950
# 2             GB              BL        NaN                 NaN
# 3            MDZ             MSB        NaN                 NaN
# 4            ONB             ONB        NaN                 NaN
#
#    secondary_references                                   general_comments  \
# 0          Soranzo 2019         The 1518 Basel version is also in Noscemus
# 1                   NaN  There is a prior, 1514 edition of De secretis ...
# 2                   NaN  This book was first published in 1518 with an ...
# 3                   NaN  This 1519 book is catalogued wrongly by many l...
# 4                   NaN          Dedicated to Leonellus Marquis of Estense
#
#    OTHER                                           filename Unnamed: 64
# 0    NaN  Augurello,_Giovanni_Aurelio_-_Chrysopoeia__Ven...         NaN
# 1    NaN        Pseudo-Lull1518_De_secretis_naturae_MDZ.pdf         NaN
# 2    NaN  Pantheus1518_Ars_Transmutationis_Metallicae_BL...         NaN
# 3    NaN  Pantheus1519_Commentarium_Transmutationis_Meta...         NaN
# 4    NaN                  Pantheus1530_Voarchadumia_ONB.pdf         NaN
#
# [5 rows x 65 columns]

# %%
emlap_metadata.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 emlap_metadata.columns
#
# NameError: name 'emlap_metadata' is not defined

# %%
# test loading individual file
work_id = 100001
dir = "../data/sents_data/"
filename = str(work_id) + ".json"
with open(dir + filename, "r") as f:
    sents_data = json.load(f)
# look at a random selection of morphologically annotated and lemmatized sentences
sents_data[200:210]
# Out:
# [[100001,
#   200,
#   'Aut animam dicas:',
#   [['Aut', 'aut', 'CCONJ', [0, 3], [17], [12]],
#    ['animam', 'anima', 'NOUN', [4, 10], [17], [12]],
#    ['dicas', 'dico', 'VERB', [11, 16], [17], [12]],
#    [':', ':', 'PUNCT', [16, 17], [17], [12]]]],
#  [100001,
#   201,
#   'sed eum:',
#   [['sed', 'sed', 'CCONJ', [0, 3], [17], [12]],
#    ['eum', 'is', 'PRON', [4, 7], [17], [12]],
#    [':', ':', 'PUNCT', [7, 8], [17], [12]]]],
#  [100001,
#   202,
#   'qui solus utroque Participans in idem simul haec extrema reducat.',
#   [['qui', 'qui', 'PRON', [0, 3], [17], [12]],
#    ['solus', 'solus', 'DET', [4, 9], [17], [12]],
#    ['utroque', 'uterque', 'DET', [10, 17], [17], [12]],
#    ['Participans', 'participo', 'VERB', [18, 29], [17], [13]],
#    ['in', 'in', 'ADP', [30, 32], [17], [13]],
#    ['idem', 'idem', 'DET', [33, 37], [17], [13]],
#    ['simul', 'simul', 'ADV', [38, 43], [17], [13]],
#    ['haec', 'hic', 'DET', [44, 48], [17], [13]],
#    ['extrema', 'extremus', 'ADJ', [49, 56], [17], [13]],
#    ['reducat', 'reduco', 'VERB', [57, 64], [17], [13]],
#    ['.', '.', 'PUNCT', [64, 65], [17], [13]]]],
#  [100001,
#   203,
#   'Hic igitur maria:',
#   [['Hic', 'hic', 'DET', [0, 3], [17], [14]],
#    ['igitur', 'igitur', 'PART', [4, 10], [17], [14]],
#    ['maria', 'mare', 'NOUN', [11, 16], [17], [14]],
#    [':', ':', 'PUNCT', [16, 17], [17], [14]]]],
#  [100001,
#   204,
#   'ac terras:',
#   [['ac', 'atque', 'CCONJ', [0, 2], [17], [14]],
#    ['terras', 'terra', 'NOUN', [3, 9], [17], [14]],
#    [':', ':', 'PUNCT', [9, 10], [17], [14]]]],
#  [100001,
#   205,
#   'atque aera:',
#   [['atque', 'atque', 'CCONJ', [0, 5], [17], [14]],
#    ['aera', 'aer', 'NOUN', [6, 10], [17], [14]],
#    [':', ':', 'PUNCT', [10, 11], [17], [14]]]],
#  [100001,
#   206,
#   '& ignem Uiuereque:',
#   [['&', '&', 'PUNCT', [0, 1], [17], [14]],
#    ['ignem', 'ignis', 'NOUN', [2, 7], [17], [14]],
#    ['Uiuere', 'uiuo', 'VERB', [8, 14], [17], [15]],
#    ['que', 'que', 'CCONJ', [14, 17], [17], [15]],
#    [':', ':', 'PUNCT', [17, 18], [17], [15]]]],
#  [100001,
#   207,
#   'augerique:',
#   [['augeri', 'augeo', 'VERB', [0, 6], [17], [15]],
#    ['que', 'que', 'CCONJ', [6, 9], [17], [15]],
#    [':', ':', 'PUNCT', [9, 10], [17], [15]]]],
#  [100001,
#   208,
#   'atque in se cuncta referre Semper auet:',
#   [['atque', 'atque', 'CCONJ', [0, 5], [17], [15]],
#    ['in', 'in', 'ADP', [6, 8], [17], [15]],
#    ['se', 'sui', 'PRON', [9, 11], [17], [15]],
#    ['cuncta', 'cunctus', 'DET', [12, 18], [17], [15]],
#    ['referre', 'refero', 'VERB', [19, 26], [17], [15]],
#    ['Semper', 'semper', 'ADV', [27, 33], [17], [16]],
#    ['auet', 'aueo', 'VERB', [34, 38], [17], [16]],
#    [':', ':', 'PUNCT', [38, 39], [17], [16]]]],
#  [100001,
#   209,
#   'semper stirpes:',
#   [['semper', 'semper', 'ADV', [0, 6], [17], [16]],
#    ['stirpes', 'stirpes', 'NOUN', [7, 14], [17], [16]],
#    [':', ':', 'PUNCT', [14, 15], [17], [16]]]]]

# %%
# function to load sentence data from any EMLAP text based on its ID
def load_sentences_data(id):
    dir = "data/sents_data"
    filename = str(work_id) + ".json"
    url = "https://raw.githubusercontent.com/CCS-ZCU/EMLAP_ETL/refs/heads/master/{0}/{1}".format(dir,filename)
    resp = requests.get(url)
    sents_data = resp.json()
    return sents_data

# %%
# load the sentence data from all texts into one list
emlap_sents_data = []
for no in emlap_metadata["No."]:
   sents_data = load_sentences_data(no)
   for sent_data in sents_data:
        emlap_sents_data.append(sent_data)

# %%
def get_phrase_instances(phrase):
    phrase_instances = []
    if phrase is not None:
        phrase = phrase.lower().replace("v", "u")
        for sent_data in emlap_sents_data:
            try:
                lemmata_string = " ".join([t[1].lower().replace("v", "u") for t in sent_data[3]])
                # regular expression for detecting presence of phrase in lemmata string, it has to match only cases
                # where there is a space or beginning/end of the string immediatelly before/after the phrase instance in the lemmata string
                if re.search(r"\b" + phrase + r"\b", lemmata_string) is not None:
                    phrase_instances.append((sent_data[0], sent_data[1], sent_data[2]))
            except:
                pass
    return phrase_instances

# %%
# look at all dictionary entries containing "Mercurius"
entries_df[entries_df["Lemma"].str.contains("Mercurius", na=False)]
# Out:
#                                          ID  \
# 2049                   Ruland1612-Mercurius
# 2051     Ruland1612-Mercurius-crystallinus,
# 2052        Ruland1612-Mercurius-corallinus
# 2053            Ruland1612-Mercurius-crudus
# 2054             Ruland1612-Mercurius-laxus
# 2055  Ruland1612-Mercurius-argentipigmentum
# 2056        Ruland1612-Mercurius-metallorum
# 2057                   Ruland1612-Mercurius
# 2058                   Ruland1612-Mercurius
# 2059       Ruland1612-Mercurius-regeneratus
# 2060           Ruland1612-Mercurius-chambar
# 2062        Ruland1612-Mercurius-mineralium
# 2063        Ruland1612-Mercurius-metallorum
#
#                                               entry_xml Type XML_ID  \
# 2049  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2051  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2052  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2053  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2054  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2055  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2056  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2057  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2058                                         [[[], []]]    M   None
# 2059  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2060  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2062  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
# 2063  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...    M   None
#
#                            Lemma Phrase Variants Notes  \
# 2049                   Mercurius   None       []    []
# 2051     Mercurius crystallinus,   None       []    []
# 2052        Mercurius corallinus   None       []    []
# 2053            Mercurius crudus   None       []    []
# 2054             Mercurius laxus   None       []    []
# 2055  Mercurius argentipigmentum   None       []    []
# 2056        Mercurius metallorum   None       []    []
# 2057                   Mercurius   None       []    []
# 2058                   Mercurius   None       []    []
# 2059       Mercurius regeneratus   None       []    []
# 2060           Mercurius chambar   None       []    []
# 2062        Mercurius mineralium   None       []    []
# 2063        Mercurius metallorum   None       []    []
#
#                                             Definitions  \
# 2049  [id est, sulphur.                      Mercuri...
# 2051  [qui saepe sublimatus est in formam cry¬stalli...
# 2052  [qui per oleum ouorum &               aquas al...
# 2053  [est is, qui nondum separatus est a sua matric...
# 2054                            [est turbith minerale.]
# 2055  [ist Schwefel victriol, Alaun Saltz-dieweils d...
# 2056  [Ist darauß die Natur der Coͤrper gezo¬gen wir...
# 2057  [est principium materiale, vaporosum, naturę a...
# 2058                         [argentum viuum CC. S. Z.]
# 2059                         [est primum ens Mercurii.]
# 2060       [ist magnesia, fuessend Coͤrper und Wasser.]
# 2062  [est oleitas, vel vnctuositas de mineris auri ...
# 2063  [mercurius corporis                 praecipita...
#
#                                            Translations  \
# 2049  [Mercurius ist in allen Chymistischen Buͤchern...
# 2051                                                 []
# 2052                                                 []
# 2053                      [der noch in seim Ertz liget]
# 2054                                                 []
# 2055                     [ist Schwefel victriol, Alaun]
# 2056           [Ist darauß die Natur der Coͤrper gezo¬]
# 2057                                                 []
# 2058                                                 []
# 2059                                                 []
# 2060       [ist magnesia, fuessend Coͤrper und Wasser.]
# 2062            [Das Oel auß dem Gold oder Silber Ertz]
# 2063          [Wann die Metallen in ihr erste materiam]
#
#                     relemmatized
# 2049                   mercurius
# 2051      mercurius crystallinus
# 2052        mercurius corallinus
# 2053            mercurius crudus
# 2054             mercurius laxus
# 2055  mercurius argentipigmentus
# 2056          mercurius metallum
# 2057                   mercurius
# 2058                   mercurius
# 2059          mercurius regenero
# 2060           mercurius chambar
# 2062         mercurius mineralis
# 2063          mercurius metallum

# %%
# check with a simple one word phrase
output = get_phrase_instances("aqua")
len(output)
# Out:
# 16821

# %%
# look at first 10 instances
output[:10]
# Out:
# [(100001,
#   530,
#   'argento nec minus ipsi Uiuo etiam terrae partes miscentur in omnis Prorsus aquae partes nullo discrimine iunctae.'),
#  (100001, 629, 'Tantus aquae uigor est:'),
#  (100001, 668, 'Acris aquae hoc etiam dirae uiolentia rodit:'),
#  (100001, 682, 'haec nanque potent ia caelo Caelestis descendit aquae:'),
#  (100001, 2793, 'uina permutans Aquis?'),
#  (100002,
#   91,
#   'Que uero mutat duram materiam ad principium nature sui ad finem, quod sit apta ad genera tionem ad recipiendum uirtutes in aquis infusas fortium mineralium uirtutum, sicuti ipsam & accipit & recipit uirtutem informatiuam embrionis.'),
#  (100002,
#   100,
#   '& illas quoque includimus in aquis grauidis ex uirtutibus minera ibus ad hunc finem:'),
#  (100002,
#   145,
#   'PIn primo em non consideramus nisi aquas aereas, in duobus uero ultimis aereas & terreas.'),
#  (100002,
#   156,
#   'Et cum hoc sufficit tibi modus generalis, aquarum tam uegetabilium quam mineralium ad medicinam humanam & lapidem philosophorum, & lapides preciosos, & hec est regula generalis.'),
#  (100002,
#   219,
#   '& distilla aquam ardentem, sicut consuetum est per cannas brachiales eris:')]

# %%
# repeat the same with a multiword phrase (all words lemmatized)
output = get_phrase_instances("mercurius metallum")
len(output)
# Out:
# 27

# %%
output[:10]
# Out:
# [(100007,
#   1188,
#   'Uiuum causat metalla quamuis adhuc bene differunt unum ab alio, secundum quod plus existit uiscositate terrae infectum, cum tamen sulphur simplex uiuum causans aurum & argentum non est nisi uapor calidus & siccus generatus ex purissima siccitate terrestri, in qua omnibus moribus predominatur ignis, & illud dicitur elementum cum mercurio metallorum &c. sulphur patet supra.'),
#  (100010,
#   404,
#   'Compraehendis igitur ex supradictis rationibus, nostrum argentum uiuum, non esse argenturm uiuum, sed sal in similitudine uerae calcis communis, quia argentum uiuum, siue mercurius metallorum per calcinationem & reductionem conuertitur in sal, ut manifeste apparet per totum librum testamenti.'),
#  (100010,
#   504,
#   'Prius diximus, per calcinationem, mercurium metallorum, conuerti in sal, Cum uero hoc sal multum terrestreitatis habeat, inde certam fixionem acquisiuit.'),
#  (100011,
#   3739,
#   'Uiuum causat metalla, quamuis unum differt ab alio secundum quod plus existit uiscositate terrae infectum, cum tamen Sulphur simplex uiuum, causans Aurum & Argentum, non est nisi uapor calidus & siccus, generatus ex purissima siccitate terrestri, in quo omnibus modis praedominatur ignis, & illud dicitur elementum cum Mercurio metallorum.'),
#  (100016, 5803, 'car. 137 Mercurii metallorum quomodo differant.'),
#  (100022,
#   129,
#   'Uiuum causat metalla, quamuis adhuc bene differunt unum ab alio, secundum quod plus existit uiscositate terrae infectum, cum tamen sulphur simplex uiuum, causans aurum et argentum, non est nisi uapor calidus et siccus, generatus ex purissima siccitate terrestri, in qua omnibus moribus praedominatur ignis, & illud dicitur elementum cum Mercurio metallorum.'),
#  (100022,
#   305,
#   'Si esset possibile, tunc sequeretur, quod de nouo extra primam materiam Mercurium metallorum, ars componeret elementa, & uiceuersa ars generaret Mercurium sicut destruxit, quod impossibile est artificialiter fieri.'),
#  (100029,
#   457,
#   'Obseruandum igitur in Elixiris insequentibus sulphur eorum, quae isti minoralia uocant, quintam essentiam esse mercurium metallorum, ex quibus elicitur natura corporis:'),
#  (100033,
#   433,
#   'nec alia aqua uitae metallica & mercurialis, nec alia lapidis aqua quoniam uulgi mercurii praeparatio hec omnia in sese continet. 132 Quilibet mercurius metallorum & mineralium gradibus successiuis potest per coqui & exaltari in qualitatem usque mercuriorum omnium aliorum corporum usque ad corpus solare, indeque deduci ad eum gradum & uirtutem corporis metallici ad quem uolueris. 133 Mercurius uulgi ante legitimam praeparationem, mercurius philosophorum non est:'),
#  (100035, 841, 'secunda, mercurio metallorum:')]

# %%
entries_df["emlap_instances"] = entries_df["relemmatized"].apply(get_phrase_instances)

# %%
entries_df["emlap_instances_N"] = entries_df["emlap_instances"].apply(len)

# %%
entries_df.sort_values("emlap_instances_N", ascending=False)[:20]
# Out:
#                         ID                                          entry_xml  \
# 1620       Ruland1612-Hunc  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 396        Ruland1612-Aqua  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 1044     Ruland1612-Corpus  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 1640      Ruland1612-Ignis  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 1641      Ruland1612-Ignis  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2498      Ruland1612-Rebus  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 545       Ruland1612-Aurum  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2222      Ruland1612-Oleum  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2217      Ruland1612-Oleum  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2216      Ruland1612-Oleum  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2785   Ruland1612-Spiritus  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2073   Ruland1612-Metallum  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2071   Ruland1612-Metallum  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2853    Ruland1612-Sulphur  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2852    Ruland1612-Sulphur  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2854    Ruland1612-Sulphur  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2851    Ruland1612-Sulphur  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 168       Ruland1612-Album  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2057  Ruland1612-Mercurius  [[[], [<Element '{http://www.tei-c.org/ns/1.0}...
# 2058  Ruland1612-Mercurius                                         [[[], []]]
#
#      Type XML_ID      Lemma Phrase Variants  \
# 1620    H   None       Hunc   None       []
# 396     A   None       Aqua   None       []
# 1044    C   None     Corpus   None       []
# 1640    I   None      Ignis   None       []
# 1641    I   None      Ignis   None       []
# 2498    R   None      Rebus   None       []
# 545     A   None      Aurum   None       []
# 2222    O   None      Oleum   None       []
# 2217    O   None      Oleum   None       []
# 2216    O   None      Oleum   None       []
# 2785    S   None   Spiritus   None       []
# 2073    M   None   Metallum   None       []
# 2071    M   None   Metallum   None       []
# 2853    S   None    Sulphur   None       []
# 2852    S   None    Sulphur   None       []
# 2854    S   None    Sulphur   None       []
# 2851    S   None    Sulphur   None       []
# 168     A   None      Album   None       []
# 2057    M   None  Mercurius   None       []
# 2058    M   None  Mercurius   None       []
#
#                                                   Notes  \
# 1620                                                 []
# 396   [1. Dieses Wasser reiniget/maschet/meitet/mach...
# 1044                                                 []
# 1640                                                 []
# 1641                                                 []
# 2498                                                 []
# 545   [Natiuum purum, quod a natura tale est, cuius ...
# 2222                                                 []
# 2217                                                 []
# 2216                                                 []
# 2785                                                 []
# 2073                                                 []
# 2071                                                 []
# 2853                                                 []
# 2852                                                 []
# 2854                                                 []
# 2851                                                 []
# 168                                                  []
# 2057                                                 []
# 2058                                                 []
#
#                                             Definitions  \
# 1620              [id est, Iupiter, stannum vel hucci.]
# 396   [, id est, liquor,                          da...
# 1044  [Clang. Buce.                          Der Coͤ...
# 1640  [Ist nach etlicher Meinung das Oel sokauff der...
# 1641  [Ignis pro lapide philos.                     ...
# 2498  [vltima rerum materia,                        ...
# 545   [, à Germanis                          Goldtsa...
# 2222                    [est Destillatum aut Secretum.]
# 2217  [heist auch das erste Wass. ridas von sanguine...
# 2216  [id est, ignis,                             wi...
# 2785  [est aqua soluens è re simplici, & acri produc...
# 2073                      [id est, conflatum argentum.]
# 2071  [vena,                             Ertz       ...
# 2853  [est principium formatiuum, aereum partim, par...
# 2852  [a Germanis                          Schwefel ...
# 2854  [ist der Saam dieses steins / ond ist zweyerle...
# 2851  [chibur, vel, Albusao Arabice dicitur, pars   ...
# 168   [, id est,                          Weiß Kupff...
# 2057  [est principium materiale, vaporosum, naturę a...
# 2058                         [argentum viuum CC. S. Z.]
#
#                                            Translations relemmatized  \
# 1620                                                 []          hic
# 396   [das Wasser ist auch immer darvonnen / da¬, Au...         aqua
# 1044        [Der Coͤrper ist ein metallisch Wesen/dar¬]       corpus
# 1640  [Ist nach etlicher Meinung das Oel sokauff der...        ignis
# 1641                     [Bernhardus sagt: Das habe er]        ignis
# 2498                     [die letzte Matery aller Ding]          res
# 545   [Goldtsa, Goldt ist der Coͤrper / ond ferment ...        aurum
# 2222                                                 []        oleum
# 2217  [heist auch das erste Wass. ridas von sanguine...        oleum
# 2216  [wirdt außgezogen von einer trocknen Sub¬, dis...        oleum
# 2785  [Spiritus heist die innerliche Krafft/ darinne...     spiritus
# 2073                                                 []     metallum
# 2071                                             [Ertz]     metallum
# 2853                                                 []      sulphur
# 2852                                         [Schwefel]      sulphur
# 2854  [ist der Saam dieses steins / ond ist zweyerle...      sulphur
# 2851                                                 []      sulphur
# 168                                      [Weiß Kupffer]        albus
# 2057                                                 []    mercurius
# 2058                                                 []    mercurius
#
#                                         emlap_instances  \
# 1620  [(100001, 6, & Musis hanc commendauimus almis ...
# 396   [(100001, 530, argento nec minus ipsi Uiuo eti...
# 1044  [(100001, 101, & uasto uenas sub corpore condi...
# 1640  [(100001, 127, Tu molli e gremio surgens uxori...
# 1641  [(100001, 127, Tu molli e gremio surgens uxori...
# 2498  [(100001, 4, Ut rerum inuolucris tantarum euol...
# 545   [(100001, 76, Interea certis hominum uis ulla ...
# 2222  [(100001, 2245, Nunc oleo demissa leues:), (10...
# 2217  [(100001, 2245, Nunc oleo demissa leues:), (10...
# 2216  [(100001, 2245, Nunc oleo demissa leues:), (10...
# 2785  [(100001, 137, feruens Dulcis mihi spiritus or...
# 2073  [(100001, 77, & mutare Metalla Percipias primu...
# 2071  [(100001, 77, & mutare Metalla Percipias primu...
# 2853  [(100001, 385, Sulphura ubi argento feruent im...
# 2852  [(100001, 385, Sulphura ubi argento feruent im...
# 2854  [(100001, 385, Sulphura ubi argento feruent im...
# 2851  [(100001, 385, Sulphura ubi argento feruent im...
# 168   [(100001, 1275, album Non tamen excipies:), (1...
# 2057  [(100002, 235, P Facta per multos dies in uase...
# 2058  [(100002, 235, P Facta per multos dies in uase...
#
#                                           instances_ids  emlap_instances_N
# 1620  [100001, 100001, 100001, 100001, 100001, 10000...              31023
# 396   [100001, 100001, 100001, 100001, 100001, 10000...              16821
# 1044  [100001, 100001, 100001, 100001, 100001, 10000...              10750
# 1640  [100001, 100001, 100001, 100001, 100001, 10000...              10030
# 1641  [100001, 100001, 100001, 100001, 100001, 10000...              10030
# 2498  [100001, 100001, 100001, 100001, 100001, 10000...               8056
# 545   [100001, 100001, 100001, 100001, 100001, 10000...               6636
# 2222  [100001, 100002, 100002, 100002, 100002, 10000...               6292
# 2217  [100001, 100002, 100002, 100002, 100002, 10000...               6292
# 2216  [100001, 100002, 100002, 100002, 100002, 10000...               6292
# 2785  [100001, 100001, 100001, 100001, 100001, 10000...               5806
# 2073  [100001, 100001, 100001, 100001, 100001, 10000...               4886
# 2071  [100001, 100001, 100001, 100001, 100001, 10000...               4886
# 2853  [100001, 100001, 100001, 100001, 100001, 10000...               4533
# 2852  [100001, 100001, 100001, 100001, 100001, 10000...               4533
# 2854  [100001, 100001, 100001, 100001, 100001, 10000...               4533
# 2851  [100001, 100001, 100001, 100001, 100001, 10000...               4533
# 168   [100001, 100001, 100001, 100002, 100002, 10000...               4058
# 2057  [100002, 100002, 100002, 100002, 100002, 10000...               3929
# 2058  [100002, 100002, 100002, 100002, 100002, 10000...               3929

# %%
entries_df["instances_ids"] = entries_df["emlap_instances"].apply(lambda x: [ins[0] for ins in x])

# %%
entries_df.to_json("../data/large_files/ruland-emlap.json")
