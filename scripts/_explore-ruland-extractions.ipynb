# %%
import pandas as pd

# %%
test_df = pd.read_parquet("../data/large_files/emlap_ruland_instances/mercurius_metallorum.parquet")
test_df.head(5)
# Out:
#              target_phrase   target_from matched_by         target_lemmata  \
# 0   [Mercurio, metallorum]  relemmatized      lemma  [mercurius, metallum]
# 1   [mercurio, metallorum]  relemmatized      lemma  [mercurius, metallum]
# 2  [mercurius, metallorum]  relemmatized      lemma  [mercurius, metallum]
# 3  [mercurium, metallorum]  relemmatized      lemma  [mercurius, metallum]
# 4   [Mercurio, metallorum]  relemmatized      lemma  [mercurius, metallum]
#
#          target_token_ids target_kwic_idx target_sent_idx      grela_id  \
# 0  [353223376, 353223377]        [10, 11]        [53, 54]  emlap_100004
# 1  [354467395, 354467396]        [10, 11]        [53, 54]  emlap_100007
# 2  [350152161, 350152162]        [10, 11]        [28, 29]  emlap_100010
# 3  [350154009, 350154010]        [10, 11]          [6, 7]  emlap_100010
# 4  [356302332, 356302333]        [10, 11]        [54, 55]  emlap_100011
#
#   target_sentence_id  start_sentence_id    end_sentence_id  \
# ...
